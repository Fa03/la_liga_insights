# %% [markdown]
# # Invocación de la clase GestorBaseDatos y procesador EDA

# %% [markdown]
# ### Importacion de módulos locales

# %%
import sys
import os

# Para invocar clases guardadas en otra carpetas
sys.path.append(os.path.abspath("C:/Users/fab_t/OneDrive/CUC/PrograII/la_liga_insights/src/basedatos/"))
from GestorBaseDatos import CargaDatos

sys.path.append(os.path.abspath("C:/Users/fab_t/OneDrive/CUC/PrograII/la_liga_insights/src/eda/"))
from analisisEstadistico import ProcesadorEDA

# %% [markdown]
# ### Creación de objeto de la clase CargaDatos, conexión e insercion  de datos.

# %%
# Creación de objeto de la clase CargaDatos
gestionBD = CargaDatos('AZUSFA\\FA_LOCALSERVER', 'La_Liga_Insights', 'C:/Users/fab_t/OneDrive/CUC/PrograII/la_liga_insights/data/partidos-laliga-2024-2025.csv', ['partidos'])

# Invocación de metodo para conexión

gestionBD.conectar()

# gestionBD.insertar_datos() *** Comentado por que ya si hizo la inserción de datos!
# Out:
# ✅ Conexión establecida con SQLAlchemy

# %% [markdown]
# ### Invocación de métodos de la clase CargaDatos

# %%
print(gestionBD.get_partido(123))
print(gestionBD.get_por_equipo("Barcelona"))
print(gestionBD.get_por_temporada(2024))
print(gestionBD.home_advantage())
# Out:
#    id_partido  temporada       fecha equipo_local equipo_visita  goles_local  \
# 0         123       2024  2024-11-10        Betis         Celta            2
#
#    goles_visita xg_local xg_visita posesion_local  ... rojas_local  \
# 0             2     None      None           None  ...           0
#
#    rojas_visita  tiros_local  tiros_visita  tiros_a_puerta_local  \
# 0             0           19             3                     6
#
#    tiros_a_puerta_visita  corners_local  corners_visita  faltas_local  \
# 0                      2              2               0            12
#
#    faltas_visita
# 0              8
#
# [1 rows x 23 columns]
#     id_partido  temporada       fecha equipo_local equipo_visita  goles_local  \
# 0            6       2024  2024-08-17     Valencia     Barcelona            1
# 1           14       2024  2024-08-24    Barcelona    Ath Bilbao            2
# 2           23       2024  2024-08-27    Vallecano     Barcelona            1
# 3           30       2024  2024-08-31    Barcelona    Valladolid            7
# 4           46       2024  2024-09-15       Girona     Barcelona            1
# 5           60       2024  2024-09-22   Villarreal     Barcelona            1
# 6           67       2024  2024-09-25    Barcelona        Getafe            1
# 7           75       2024  2024-09-28      Osasuna     Barcelona            4
# 8           88       2024  2024-10-06       Alaves     Barcelona            0
# 9           99       2024  2024-10-20    Barcelona       Sevilla            5
# 10         105       2024  2024-10-26  Real Madrid     Barcelona            0
# 11         115       2024  2024-11-03    Barcelona       Espanol            3
# 12         127       2024  2024-11-10     Sociedad     Barcelona            1
# 13         133       2024  2024-11-23        Celta     Barcelona            2
# 14         139       2024  2024-11-30    Barcelona    Las Palmas            1
# 15         148       2024  2024-12-03     Mallorca     Barcelona            1
# 16         152       2024  2024-12-07        Betis     Barcelona            2
# 17         169       2024  2024-12-15    Barcelona       Leganes            0
# 18         176       2024  2024-12-21    Barcelona    Ath Madrid            1
# 19         195       2024  2025-01-18       Getafe     Barcelona            1
# 20         209       2024  2025-01-26    Barcelona      Valencia            7
# 21         216       2024  2025-02-02    Barcelona        Alaves            1
# 22         229       2024  2025-02-09      Sevilla     Barcelona            1
# 23         240       2024  2025-02-17    Barcelona     Vallecano            1
# 24         245       2024  2025-02-22   Las Palmas     Barcelona            0
# 25         257       2024  2025-03-02    Barcelona      Sociedad            4
# 26         278       2024  2025-03-16   Ath Madrid     Barcelona            2
# 27         279       2024  2025-03-27    Barcelona       Osasuna            3
# 28         285       2024  2025-03-30    Barcelona        Girona            4
# 29         294       2024  2025-04-05    Barcelona         Betis            1
# 30         304       2024  2025-04-12      Leganes     Barcelona            0
# 31         312       2024  2025-04-19    Barcelona         Celta            4
# 32         321       2024  2025-04-22    Barcelona      Mallorca            1
# 33         335       2024  2025-05-03   Valladolid     Barcelona            1
# 34         348       2024  2025-05-11    Barcelona   Real Madrid            4
# 35         359       2024  2025-05-15      Espanol     Barcelona            0
# 36         362       2024  2025-05-18    Barcelona    Villarreal            2
# 37         380       2024  2025-05-25   Ath Bilbao     Barcelona            0
#
#     goles_visita xg_local xg_visita posesion_local  ... rojas_local  \
# 0              2     None      None           None  ...           0
# 1              1     None      None           None  ...           0
# 2              2     None      None           None  ...           0
# 3              0     None      None           None  ...           0
# 4              4     None      None           None  ...           0
# 5              5     None      None           None  ...           0
# 6              0     None      None           None  ...           0
# 7              2     None      None           None  ...           0
# 8              3     None      None           None  ...           0
# 9              1     None      None           None  ...           0
# 10             4     None      None           None  ...           0
# 11             1     None      None           None  ...           0
# 12             0     None      None           None  ...           0
# 13             2     None      None           None  ...           0
# 14             2     None      None           None  ...           0
# 15             5     None      None           None  ...           0
# 16             2     None      None           None  ...           0
# 17             1     None      None           None  ...           0
# 18             2     None      None           None  ...           0
# 19             1     None      None           None  ...           0
# 20             1     None      None           None  ...           0
# 21             0     None      None           None  ...           0
# 22             4     None      None           None  ...           0
# 23             0     None      None           None  ...           0
# 24             2     None      None           None  ...           0
# 25             0     None      None           None  ...           0
# 26             4     None      None           None  ...           0
# 27             0     None      None           None  ...           0
# 28             1     None      None           None  ...           0
# 29             1     None      None           None  ...           0
# 30             1     None      None           None  ...           0
# 31             3     None      None           None  ...           0
# 32             0     None      None           None  ...           0
# 33             2     None      None           None  ...           0
# 34             3     None      None           None  ...           0
# 35             2     None      None           None  ...           1
# 36             3     None      None           None  ...           0
# 37             3     None      None           None  ...           0
#
#     rojas_visita  tiros_local  tiros_visita  tiros_a_puerta_local  \
# 0              0            6            18                     1
# 1              0           13             9                     5
# 2              0            8            22                     4
# 3              0           23             5                    10
# 4              1            9            20                     4
# 5              0           13            17                     4
# 6              0           16             7                     4
# 7              0           11            12                     6
# 8              0           11            14                     2
# 9              0           21             7                     9
# 10             0            9            15                     4
# 11             0           14            10                     9
# 12             0           14            11                     6
# 13             1           15             9                     8
# 14             0           27             5                     8
# 15             0            6            20                     1
# 16             0           12             9                     6
# 17             0           20             6                     4
# 18             0           19             5                     7
# 19             0           10            21                     4
# 20             0           22             7                    11
# 21             0           11             3                     4
# 22             1            8            10                     4
# 23             0           14             9                     5
# 24             0           10            15                     2
# 25             1           33             0                    10
# 26             0            7            13                     2
# 27             0           19             4                     5
# 28             0           21             4                     9
# 29             0           13             6                     5
# 30             0            6            12                     1
# 31             0           18            11                     6
# 32             0           40             4                    13
# 33             0            5            24                     4
# 34             0           23             9                     9
# 35             0            9            12                     1
# 36             0           24             7                     9
# 37             0           10            13                     1
#
#     tiros_a_puerta_visita  corners_local  corners_visita  faltas_local  \
# 0                       8              3               8            11
# 1                       2              5               6            11
# 2                       5              6               6            17
# 3                       2             10               1             6
# 4                       9              1               6            13
# 5                      10              7               3            12
# 6                       1              7               5             4
# 7                       5              5               8            13
# 8                       8             11               3            13
# 9                       1              5               5             6
# 10                      7             10               3            15
# 11                      3              9               5            13
# 12                      0              7               6            17
# 13                      4              5               1            13
# 14                      3              7               0             7
# 15                      9              2               5            13
# 16                      3              6               4            15
# 17                      4              8               2             5
# 18                      4             11               3            11
# 19                      5              2              10             9
# 20                      2             14               4            10
# 21                      0              5               2             8
# 22                      6              5               6            14
# 23                      4              4               5            11
# 24                      5              5               3            13
# 25                      0             12               0            15
# 26                      6              6               6            10
# 27                      0              8               4             7
# 28                      2             10               2             8
# 29                      2              9               3            16
# 30                      3              4               8            10
# 31                      8              4               1            10
# 32                      0             13               2            10
# 33                      7              4               8            12
# 34                      5             10               2            17
# 35                      4              3               3             8
# 36                      3             11               3            14
# 37                      4              2               6            21
#
#     faltas_visita
# 0              13
# 1              16
# 2              11
# 3              12
# 4               4
# 5              12
# 6              14
# 7               3
# 8               8
# 9              14
# 10             17
# 11             14
# 12              6
# 13              9
# 14             11
# 15             13
# 16             14
# 17             13
# 18              8
# 19              9
# 20             12
# 21             20
# 22              6
# 23              9
# 24              4
# 25              6
# 26             11
# 27             14
# 28             11
# 29             12
# 30              4
# 31             13
# 32              7
# 33             15
# 34             15
# 35             10
# 36              9
# 37             10
#
# [38 rows x 23 columns]
#      id_partido  temporada       fecha equipo_local equipo_visita  \
# 0             1       2024  2024-08-15   Ath Bilbao        Getafe
# 1             2       2024  2024-08-15        Betis        Girona
# 2             3       2024  2024-08-16        Celta        Alaves
# 3             4       2024  2024-08-16   Las Palmas       Sevilla
# 4             5       2024  2024-08-17      Osasuna       Leganes
# ..          ...        ...         ...          ...           ...
# 375         376       2024  2025-05-24       Getafe         Celta
# 376         377       2024  2025-05-24    Vallecano      Mallorca
# 377         378       2024  2025-05-25       Girona    Ath Madrid
# 378         379       2024  2025-05-25   Villarreal       Sevilla
# 379         380       2024  2025-05-25   Ath Bilbao     Barcelona
#
#      goles_local  goles_visita xg_local xg_visita posesion_local  ...  \
# 0              1             1     None      None           None  ...
# 1              1             1     None      None           None  ...
# 2              2             1     None      None           None  ...
# 3              2             2     None      None           None  ...
# 4              1             1     None      None           None  ...
# ..           ...           ...      ...       ...            ...  ...
# 375            1             2     None      None           None  ...
# 376            0             0     None      None           None  ...
# 377            0             4     None      None           None  ...
# 378            4             2     None      None           None  ...
# 379            0             3     None      None           None  ...
#
#     rojas_local  rojas_visita  tiros_local  tiros_visita  \
# 0             0             0            7             9
# 1             0             0           19            13
# 2             0             0            6            10
# 3             0             0           13            16
# 4             0             0           16            10
# ..          ...           ...          ...           ...
# 375           1             0            6            15
# 376           0             0           27             9
# 377           0             0            2            19
# 378           0             0           12            17
# 379           0             0           10            13
#
#      tiros_a_puerta_local  tiros_a_puerta_visita  corners_local  \
# 0                       4                      2              5
# 1                       4                      2              4
# 2                       4                      2              3
# 3                       5                      5              6
# 4                       5                      4              6
# ..                    ...                    ...            ...
# 375                     1                      8              2
# 376                     8                      2             11
# 377                     1                     11              1
# 378                     7                      6              3
# 379                     1                      4              2
#
#      corners_visita  faltas_local  faltas_visita
# 0                 6            15             12
# 1                 4            11              7
# 2                 3             8             23
# 3                 3            12             13
# 4                 4            14             12
# ..              ...           ...            ...
# 375               6            13             10
# 376               2             9             14
# 377               8            13             11
# 378               5             8             14
# 379               6            21             10
#
# [380 rows x 23 columns]
#    victorias_local  victorias_visita  empates
# 0              169               114       97

# %% [markdown]
# ## Creación de objesto clase ProcesadorEDA

# %%
df_ParaAnalisis = gestionBD.cargar_datos() # metodo está en el modulo GestorBaseDatos
estadistica = ProcesadorEDA(df_ParaAnalisis)
# Out:
# 📥 Datos cargados: 380 filas, 23 columnas

# %% [markdown]
# ### Método resumen_descriptivo

# %%
print(estadistica.resumen_descriptivo())
# Out:
# 📊 Resumen descriptivo:
#        id_partido  temporada  goles_local  goles_visita  amarillas_local  \
# count  380.000000      380.0   380.000000    380.000000       380.000000
# mean   190.500000     2024.0     1.452632      1.165789         2.157895
# std    109.840794        0.0     1.243609      1.075703         1.473178
# min      1.000000     2024.0     0.000000      0.000000         0.000000
# 25%     95.750000     2024.0     1.000000      0.000000         1.000000
# 50%    190.500000     2024.0     1.000000      1.000000         2.000000
# 75%    285.250000     2024.0     2.000000      2.000000         3.000000
# max    380.000000     2024.0     7.000000      5.000000         7.000000
#
#        amarillas_visita  rojas_local  rojas_visita  tiros_local  tiros_visita  \
# count        380.000000   380.000000    380.000000   380.000000    380.000000
# mean           2.323684     0.102632      0.102632    13.121053     10.571053
# std            1.609001     0.328896      0.320773     5.764149      4.648909
# min            0.000000     0.000000      0.000000     2.000000      0.000000
# 25%            1.000000     0.000000      0.000000     9.750000      8.000000
# 50%            2.000000     0.000000      0.000000    12.000000     10.000000
# 75%            3.000000     0.000000      0.000000    16.000000     13.000000
# max            9.000000     2.000000      2.000000    40.000000     25.000000
#
#        tiros_a_puerta_local  tiros_a_puerta_visita  corners_local  \
# count            380.000000             380.000000     380.000000
# mean               4.584211               3.552632       5.368421
# std                2.529147               2.186519       3.159114
# min                0.000000               0.000000       0.000000
# 25%                3.000000               2.000000       3.000000
# 50%                4.000000               3.000000       5.000000
# 75%                6.000000               5.000000       7.000000
# max               16.000000              11.000000      26.000000
#
#        corners_visita  faltas_local  faltas_visita
# count      380.000000    380.000000     380.000000
# mean         4.150000     12.252632      12.478947
# std          2.280148      3.963470       4.035081
# min          0.000000      1.000000       3.000000
# 25%          2.000000     10.000000      10.000000
# 50%          4.000000     12.000000      12.000000
# 75%          6.000000     15.000000      15.000000
# max         14.000000     28.000000      26.000000

# %% [markdown]
# ### Método Matriz de Correlación

# %%
## Matriz de Correlacion
print("Se muensta la correlación entre variable \n",estadistica.matriz_correlacion())
# Out:
# Se muensta la correlación entre variable
#                         id_partido  temporada  goles_local  goles_visita  \
# id_partido               1.000000        NaN    -0.021866      0.051618
# temporada                     NaN        NaN          NaN           NaN
# goles_local             -0.021866        NaN     1.000000     -0.022713
# goles_visita             0.051618        NaN    -0.022713      1.000000
# amarillas_local         -0.104797        NaN    -0.106802      0.126627
# amarillas_visita        -0.101333        NaN    -0.043084     -0.009744
# rojas_local              0.024065        NaN    -0.126777      0.123309
# rojas_visita            -0.051634        NaN     0.048597     -0.026502
# tiros_local              0.057860        NaN     0.290849     -0.086224
# tiros_visita             0.031243        NaN    -0.152988      0.287035
# tiros_a_puerta_local     0.042199        NaN     0.549903     -0.040544
# tiros_a_puerta_visita    0.077518        NaN    -0.037894      0.617196
# corners_local            0.053196        NaN     0.039377     -0.028891
# corners_visita           0.031220        NaN    -0.087280      0.037167
# faltas_local            -0.016243        NaN    -0.140492     -0.001186
# faltas_visita           -0.024342        NaN    -0.028067     -0.044481
#
#                        amarillas_local  amarillas_visita  rojas_local  \
# id_partido                   -0.104797         -0.101333     0.024065
# temporada                          NaN               NaN          NaN
# goles_local                  -0.106802         -0.043084    -0.126777
# goles_visita                  0.126627         -0.009744     0.123309
# amarillas_local               1.000000          0.252214     0.140726
# amarillas_visita              0.252214          1.000000     0.121539
# rojas_local                   0.140726          0.121539     1.000000
# rojas_visita                  0.049370          0.063270    -0.050085
# tiros_local                  -0.187757          0.011411    -0.205594
# tiros_visita                  0.143986         -0.032536     0.251476
# tiros_a_puerta_local         -0.145210          0.017598    -0.176946
# tiros_a_puerta_visita         0.056391         -0.089978     0.148402
# corners_local                -0.157103          0.040844    -0.193933
# corners_visita                0.061268         -0.045632     0.137743
# faltas_local                  0.306308          0.117886     0.004346
# faltas_visita                 0.052493          0.323936     0.123904
#
#                        rojas_visita  tiros_local  tiros_visita  \
# id_partido                -0.051634     0.057860      0.031243
# temporada                       NaN          NaN           NaN
# goles_local                0.048597     0.290849     -0.152988
# goles_visita              -0.026502    -0.086224      0.287035
# amarillas_local            0.049370    -0.187757      0.143986
# amarillas_visita           0.063270     0.011411     -0.032536
# rojas_local               -0.050085    -0.205594      0.251476
# rojas_visita               1.000000     0.118840     -0.041174
# tiros_local                0.118840     1.000000     -0.413966
# tiros_visita              -0.041174    -0.413966      1.000000
# tiros_a_puerta_local       0.137298     0.716738     -0.257792
# tiros_a_puerta_visita     -0.020889    -0.270149      0.647651
# corners_local              0.058927     0.621327     -0.356969
# corners_visita            -0.068000    -0.338048      0.541497
# faltas_local               0.066716    -0.194559      0.051577
# faltas_visita             -0.072731    -0.138403     -0.093386
#
#                        tiros_a_puerta_local  tiros_a_puerta_visita  \
# id_partido                         0.042199               0.077518
# temporada                               NaN                    NaN
# goles_local                        0.549903              -0.037894
# goles_visita                      -0.040544               0.617196
# amarillas_local                   -0.145210               0.056391
# amarillas_visita                   0.017598              -0.089978
# rojas_local                       -0.176946               0.148402
# rojas_visita                       0.137298              -0.020889
# tiros_local                        0.716738              -0.270149
# tiros_visita                      -0.257792               0.647651
# tiros_a_puerta_local               1.000000              -0.141079
# tiros_a_puerta_visita             -0.141079               1.000000
# corners_local                      0.435648              -0.207175
# corners_visita                    -0.231192               0.304572
# faltas_local                      -0.182167               0.060267
# faltas_visita                     -0.077648              -0.139534
#
#                        corners_local  corners_visita  faltas_local  \
# id_partido                  0.053196        0.031220     -0.016243
# temporada                        NaN             NaN           NaN
# goles_local                 0.039377       -0.087280     -0.140492
# goles_visita               -0.028891        0.037167     -0.001186
# amarillas_local            -0.157103        0.061268      0.306308
# amarillas_visita            0.040844       -0.045632      0.117886
# rojas_local                -0.193933        0.137743      0.004346
# rojas_visita                0.058927       -0.068000      0.066716
# tiros_local                 0.621327       -0.338048     -0.194559
# tiros_visita               -0.356969        0.541497      0.051577
# tiros_a_puerta_local        0.435648       -0.231192     -0.182167
# tiros_a_puerta_visita      -0.207175        0.304572      0.060267
# corners_local               1.000000       -0.303660     -0.131360
# corners_visita             -0.303660        1.000000     -0.055881
# faltas_local               -0.131360       -0.055881      1.000000
# faltas_visita              -0.074733       -0.083825     -0.000162
#
#                        faltas_visita
# id_partido                 -0.024342
# temporada                        NaN
# goles_local                -0.028067
# goles_visita               -0.044481
# amarillas_local             0.052493
# amarillas_visita            0.323936
# rojas_local                 0.123904
# rojas_visita               -0.072731
# tiros_local                -0.138403
# tiros_visita               -0.093386
# tiros_a_puerta_local       -0.077648
# tiros_a_puerta_visita      -0.139534
# corners_local              -0.074733
# corners_visita             -0.083825
# faltas_local               -0.000162
# faltas_visita               1.000000

# %% [markdown]
# ### Método con información de distribución de variable según columna indicada como parámetro

# %%
## Distribución Variable (extra)
print(estadistica.distribucion_variable('goles_visita'))
# Out:
#     intervalo  conteo
# 0  (0.0, 1.0]     116
# 1  (1.0, 2.0]     142
# 2  (2.0, 3.0]      81
# 3  (3.0, 4.0]      29
# 4  (4.0, 5.0]      12

# %% [markdown]
# ### Método que muesta datos atípicos en la columna indicada como parámetro

# %%
## Outliers (datos atípicos)
print(estadistica.detectar_outliers('goles_local'))
# Out:
# 🚨 Outliers detectados en goles_local:
#      id_partido  temporada       fecha equipo_local equipo_visita  \
# 29           30       2024  2024-08-31    Barcelona    Valladolid
# 208         209       2024  2025-01-26    Barcelona      Valencia
# 245         246       2024  2025-02-23   Ath Bilbao    Valladolid
#
#      goles_local  goles_visita xg_local xg_visita posesion_local  ...  \
# 29             7             0     None      None           None  ...
# 208            7             1     None      None           None  ...
# 245            7             1     None      None           None  ...
#
#     rojas_local  rojas_visita  tiros_local  tiros_visita  \
# 29            0             0           23             5
# 208           0             0           22             7
# 245           0             1           29             5
#
#      tiros_a_puerta_local  tiros_a_puerta_visita  corners_local  \
# 29                     10                      2             10
# 208                    11                      2             14
# 245                    16                      3              4
#
#      corners_visita  faltas_local  faltas_visita
# 29                1             6             12
# 208               4            10             12
# 245               4            10              5
#
# [3 rows x 23 columns]

# %% [markdown]
# ### Método que muestra la tabla de posiciones

# %%
## Para ver la tabla de posiciones para gráfico
print('Este es el dataframe de tabla posiciones \n',estadistica.tabla_posiciones())
# Out:
# C:\Users\fab_t\OneDrive\CUC\PrograII\la_liga_insights\src\eda\analisisEstadistico.py:74: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   tabla = pd.DataFrame(index=equipos, columns=['PJ', 'PG', 'PE', 'PP', 'GF', 'GC', 'DG', 'Pts']).fillna(0)
# Este es el dataframe de tabla posiciones
#           equipo  PJ  PG  PE  PP   GF  GC  DG  Pts
# 0     Barcelona  38  28   4   6  102  39  63   88
# 1   Real Madrid  38  26   6   6   78  38  40   84
# 2    Ath Madrid  38  22  10   6   68  30  38   76
# 3    Ath Bilbao  38  19  13   6   54  29  25   70
# 4    Villarreal  38  20  10   8   71  51  20   70
# 5         Betis  38  16  12  10   57  50   7   60
# 6         Celta  38  16   7  15   59  57   2   55
# 7       Osasuna  38  12  16  10   48  52  -4   52
# 8     Vallecano  38  13  13  12   41  45  -4   52
# 9      Mallorca  38  13   9  16   35  44  -9   48
# 10     Valencia  38  11  13  14   44  54 -10   46
# 11     Sociedad  38  13   7  18   35  46 -11   46
# 12       Getafe  38  11   9  18   34  39  -5   42
# 13       Alaves  38  10  12  16   38  48 -10   42
# 14      Espanol  38  11   9  18   40  51 -11   42
# 15      Sevilla  38  10  11  17   42  55 -13   41
# 16       Girona  38  11   8  19   44  60 -16   41
# 17      Leganes  38   9  13  16   39  56 -17   40
# 18   Las Palmas  38   8   8  22   40  61 -21   32
# 19   Valladolid  38   4   4  30   26  90 -64   16

# %% [markdown]
# ### Método que mustra información de tarjetas y faltas

# %%
## Para ver DF que se genera para gráfico de tarjetas
print('Tabla de Tarjetas y faltas por equipo\n',estadistica.tarjetas_faltas())
# Out:
# Tabla de Tarjetas y faltas por equipo
#           equipo  amarillas_local  amarillas_visita  faltas_local  \
# 0        Alaves             49.0              57.0         288.0
# 1    Ath Bilbao             33.0              31.0         250.0
# 2    Ath Madrid             37.0              39.0         197.0
# 3     Barcelona             24.0              40.0         189.0
# 4         Betis             39.0              35.0         199.0
# 5         Celta             40.0              44.0         233.0
# 6       Espanol             40.0              46.0         249.0
# 7        Getafe             50.0              59.0         292.0
# 8        Girona             32.0              43.0         201.0
# 9    Las Palmas             53.0              54.0         232.0
# 10      Leganes             37.0              45.0         258.0
# 11     Mallorca             34.0              46.0         214.0
# 12      Osasuna             45.0              41.0         256.0
# 13  Real Madrid             24.0              33.0         155.0
# 14      Sevilla             57.0              40.0         249.0
# 15     Sociedad             44.0              41.0         271.0
# 16     Valencia             47.0              38.0         230.0
# 17   Valladolid             49.0              44.0         230.0
# 18    Vallecano             41.0              55.0         247.0
# 19   Villarreal             45.0              52.0         216.0
#
#     faltas_visita  rojas_local  rojas_visita
# 0           324.0          5.0           0.0
# 1           232.0          1.0           2.0
# 2           209.0          2.0           1.0
# 3           179.0          0.0           3.0
# 4           230.0          1.0           3.0
# 5           227.0          1.0           4.0
# 6           249.0          1.0           0.0
# 7           309.0          3.0           4.0
# 8           236.0          1.0           1.0
# 9           216.0          1.0           3.0
# 10          245.0          5.0           1.0
# 11          248.0          4.0           2.0
# 12          251.0          0.0           0.0
# 13          176.0          0.0           4.0
# 14          242.0          5.0           3.0
# 15          230.0          1.0           3.0
# 16          212.0          1.0           0.0
# 17          228.0          3.0           2.0
# 18          275.0          2.0           1.0
# 19          224.0          2.0           2.0
